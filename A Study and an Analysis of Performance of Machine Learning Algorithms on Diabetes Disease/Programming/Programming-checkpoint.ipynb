# %%
#Installation of required libraries
import numpy as np
import pandas as pd 
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import KFold
import warnings
warnings.simplefilter(action = "ignore")

# %%
#Reading the dataset
df = pd.read_csv("C:\Program Files\Python36\Data\diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1      103             30             38       83  43.3
# 1            1      115             70             30       96  34.6
# 2            3      126             88             41      235  39.3
# 3            1      122             64             32      156  35.1
# 4           10      179             70              0        0  35.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.183   33        0
# 1                     0.529   32        1
# 2                     0.704   27        0
# 3                     0.692   30        1
# 4                     0.200   37        0

# %%
#Feature information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Descriptive statistics of the data set accessed.
df.describe([0.10,0.25,0.50,0.75,0.90,0.95,0.99]).T
# Out:
#                           count        mean         std     min     10%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   0.000
# Glucose                   768.0  120.894531   31.972618   0.000  85.000
# BloodPressure             768.0   69.105469   19.355807   0.000  54.000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.000
# Insulin                   768.0   79.799479  115.244002   0.000   0.000
# BMI                       768.0   31.992578    7.884160   0.000  23.600
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.165
# Age                       768.0   33.240885   11.760232  21.000  22.000
# Outcome                   768.0    0.348958    0.476951   0.000   0.000
#
#                                25%       50%        75%       90%        95%  \
# Pregnancies                1.00000    3.0000    6.00000    9.0000   10.00000
# Glucose                   99.00000  117.0000  140.25000  167.0000  181.00000
# ...

# %%
# The distribution of the Outcome variable was examined.
df["Outcome"].value_counts()*100/len(df)
# Out:
# 0    65.104167
# 1    34.895833
# Name: Outcome, dtype: float64

# %%
# The classes of the outcome variable were examined.
df.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
print("Max Age: " + str(df["Age"].max()) + " Min Age: " + str(df["Age"].min()))
# Out:
# Max Age: 81 Min Age: 21

# %%
# Histogram and density graphs of all variables were accessed.
fig, ax = plt.subplots(4,2, figsize=(16,16))
sns.distplot(df.Age, bins = 20, ax=ax[0,0]) 
sns.distplot(df.Pregnancies, bins = 20, ax=ax[0,1]) 
sns.distplot(df.Glucose, bins = 20, ax=ax[1,0]) 
sns.distplot(df.BloodPressure, bins = 20, ax=ax[1,1]) 
sns.distplot(df.SkinThickness, bins = 20, ax=ax[2,0])
sns.distplot(df.Insulin, bins = 20, ax=ax[2,1])
sns.distplot(df.DiabetesPedigreeFunction, bins = 20, ax=ax[3,0]) 
sns.distplot(df.BMI, bins = 20, ax=ax[3,1])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %%
df.groupby("Outcome").agg({"Pregnancies":"mean"})
# Out:
#          Pregnancies
# Outcome
# 0           3.298000
# 1           4.865672

# %%
df.groupby("Outcome").agg({"Age":"mean"})
# Out:
#                Age
# Outcome
# 0        31.190000
# 1        37.067164

# %%
df.groupby("Outcome").agg({"Age":"max"})
# Out:
#          Age
# Outcome
# 0         81
# 1         70

# %%
df.groupby("Outcome").agg({"Insulin": "mean"})
# Out:
#             Insulin
# Outcome
# 0         68.792000
# 1        100.335821

# %%
df.groupby("Outcome").agg({"Insulin": "max"})
# Out:
#          Insulin
# Outcome
# 0            744
# 1            846

# %%
df.groupby("Outcome").agg({"Glucose": "mean"})
# Out:
#             Glucose
# Outcome
# 0        109.980000
# 1        141.257463

# %%
df.groupby("Outcome").agg({"Glucose": "max"})
# Out:
#          Glucose
# Outcome
# 0            197
# 1            199

# %%
df.groupby("Outcome").agg({"BMI": "mean"})
# Out:
#                BMI
# Outcome
# 0        30.304200
# 1        35.142537

# %%
# The distribution of the outcome variable in the data was examined and visualized.
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('target')
ax[0].set_ylabel('')
sns.countplot('Outcome',data=df,ax=ax[1])
ax[1].set_title('Outcome')
plt.show()

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# Correlation matrix graph of the data set
f, ax = plt.subplots(figsize= [20,15])
sns.heatmap(df.corr(), annot=True, fmt=".2f", ax=ax, cmap = "GnBu" )
ax.set_title("Correlation Matrix", fontsize=20)
plt.show()

# %%
sns.displot(df, x="Glucose", hue='Outcome')
sns.displot(df, x="BMI", hue='Outcome')
sns.displot(df, x="BloodPressure", hue='Outcome')
sns.displot(df, x="Insulin", hue='Outcome')

# %%
sns.pairplot(df,hue="Outcome")

# %%
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1    103.0           30.0           38.0     83.0  43.3
# 1            1    115.0           70.0           30.0     96.0  34.6
# 2            3    126.0           88.0           41.0    235.0  39.3
# 3            1    122.0           64.0           32.0    156.0  35.1
# 4           10    179.0           70.0            NaN      NaN  35.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.183   33        0
# 1                     0.529   32        1
# 2                     0.704   27        0
# 3                     0.692   30        1
# 4                     0.200   37        0

# %%
# Now, we can look at where are missing values
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
diabetes_features=df.loc[:,df.columns!='Outcome']
def plot_FI(model):
    plt.figure(figsize=(8,6))
    features=8
    plt.barh(range(features),model.feature_importances_)
    plt.ylabel("Feature")
    plt.xlabel("Importance")
    plt.yticks(np.arange(features), diabetes_features)
    
    plt.ylim(-1,features)

plot_FI(tree)

# %%
from sklearn.linear_model import LogisticRegression

log_reg= LogisticRegression(random_state=42)
log_reg.fit(x_train, y_train)
accuracyLG = log_reg.score(x_test, y_test) 

#correctness

print("Accuracy with Logistic Regression :{}".format(accuracyLG))
# Out:
# Accuracy with Logistic Regression :0.7727272727272727

# %%
from sklearn.svm import SVC

sVm = SVC(random_state=1)
sVm.fit(x_train, y_train)
accuracySVM = sVm.score(x_test, y_test)

print("Accuracy with SVM is: ", accuracySVM)
# Out:
# Accuracy with SVM is:  0.762987012987013

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(x_train, y_train)
accuracyNB = nb.score(x_test, y_test)

print("Accuracy with Naive Bayes Classification:", accuracyNB)
# Out:
# Accuracy with Naive Bayes Classification: 0.7597402597402597

# %%
from sklearn.tree import DecisionTreeClassifier

dtc =DecisionTreeClassifier()
dtc.fit(x_train, y_train)
accuracyDTC = dtc.score(x_test, y_test)
print("Accuracy with Decision Tree Classification:", accuracyDTC)
# Out:
# Accuracy with Decision Tree Classification: 0.7045454545454546

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=1000, random_state=42)
rfc.fit(x_train, y_train)
accuracyRFC = rfc.score(x_test, y_test)
print("Accuracy with Random Forrest Classification:", accuracyRFC)
# Out:
# Accuracy with Random Forrest Classification: 0.7402597402597403

# %%
y_pred_lg = log_reg.predict(x_test)
y_true_lg = y_test
cm_lg = confusion_matrix(y_true_lg, y_pred_lg)

f, ax = plt.subplots(figsize = (7,7))
sns.heatmap(cm_lg, annot= True, linewidths= 0.5, linecolor = "red", fmt = ".0f", ax = ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
